# %%
import glob

import matplotlib.pyplot as plt
import numpy as np

from tqdm import tqdm

import data
import wifi_label_utils

# %%
def annotate(filename, label, avg_window_len, avg_duration=-1, debug=False):
    
    data_obj = data.Data(filename)

    # use a seconds worth of data to calculate threshold
    if avg_duration > -1:
        iq_samples = data_obj.get_samples(n_samples=int(data_obj.metadata["global"]["core:sample_rate"]*avg_duration))
    else:
        iq_samples = data_obj.get_samples()
        
    avg_pwr = wifi_label_utils.moving_average(iq_samples, avg_window_len)
    avg_pwr_db = 10*np.log10(avg_pwr)
    guess_threshold = (np.max(avg_pwr_db) + np.mean(avg_pwr_db))/2

    if debug:
        print(f"{np.max(avg_pwr_db)=}")
        print(f"{np.mean(avg_pwr_db)=}")
        print(f"{guess_threshold=}")
    
        plt.figure()
        plt.plot(avg_pwr_db[int(0*20480000e-2):int(30*20480000e-2)])
        plt.axhline(y = guess_threshold, color = 'r', linestyle = '-') 
        plt.show()
        
    wifi_label_utils.annotate_power_squelch(data_obj, label, guess_threshold, avg_window_len, skip_validate=True)

# %%
for f in tqdm(glob.glob("data/gamutrf/gamutrf-nz-nonanon-wifi/*.sigmf-meta")):
    annotate(f, label="wifi", avg_window_len=256, avg_duration=1, debug=True)
# Out:
#   0%|                                                                                    | 0/24 [00:00<?, ?it/s]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-47.41909621459716
# np.mean(avg_pwr_db)=-61.43150534907236
# guess_threshold=-54.425300781834764
#   4%|███▏                                                                        | 1/24 [00:27<10:21, 27.02s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.79896043674178
# np.mean(avg_pwr_db)=-61.62286719616636
# guess_threshold=-55.21091381645407
#   8%|██████▎                                                                     | 2/24 [00:49<08:53, 24.23s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-10000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-10000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-47.314863860112084
# np.mean(avg_pwr_db)=-61.640908697193716
# guess_threshold=-54.4778862786529
#  12%|█████████▌                                                                  | 3/24 [01:11<08:05, 23.11s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-47.836684131984235
# np.mean(avg_pwr_db)=-61.240552859955756
# guess_threshold=-54.53861849597
#  17%|████████████▋                                                               | 4/24 [01:32<07:29, 22.47s/it]
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-47.9807026638734
# np.mean(avg_pwr_db)=-62.099856447529106
# guess_threshold=-55.040279555701254
#  21%|███████████████▊                                                            | 5/24 [01:35<04:52, 15.37s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-10000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-10000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.250949701736516
# np.mean(avg_pwr_db)=-61.53110360864229
# guess_threshold=-54.89102665518941
#  25%|███████████████████                                                         | 6/24 [01:57<05:18, 17.68s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-10000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-10000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.584343401330955
# np.mean(avg_pwr_db)=-61.07932898497534
# guess_threshold=-54.83183619315315
#  29%|██████████████████████▏                                                     | 7/24 [02:22<05:39, 19.97s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-10000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-10000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.61315321170159
# np.mean(avg_pwr_db)=-60.954718188284936
# guess_threshold=-54.783935699993265
#  33%|█████████████████████████▎                                                  | 8/24 [02:46<05:42, 21.39s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.17865073826673
# np.mean(avg_pwr_db)=-61.8946759920068
# guess_threshold=-55.03666336513677
#  38%|████████████████████████████▌                                               | 9/24 [03:10<05:33, 22.26s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.33076784392269
# np.mean(avg_pwr_db)=-61.20550145350946
# guess_threshold=-54.76813464871608
#  42%|███████████████████████████████▎                                           | 10/24 [03:35<05:24, 23.17s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-5-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.25981800936511
# np.mean(avg_pwr_db)=-61.84604523317896
# guess_threshold=-55.05293162127204
#  46%|██████████████████████████████████▍                                        | 11/24 [04:01<05:09, 23.81s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-10000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-10000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-49.10122800843212
# np.mean(avg_pwr_db)=-61.83549710791542
# guess_threshold=-55.46836255817377
#  50%|█████████████████████████████████████▌                                     | 12/24 [04:26<04:50, 24.20s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.390863536473034
# np.mean(avg_pwr_db)=-59.90564315623118
# guess_threshold=-54.14825334635211
#  54%|████████████████████████████████████████▋                                  | 13/24 [04:52<04:31, 24.66s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.4525790513502
# np.mean(avg_pwr_db)=-61.22111059700662
# guess_threshold=-54.836844824178414
#  58%|███████████████████████████████████████████▊                               | 14/24 [05:15<04:02, 24.22s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-3-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.44998317656899
# np.mean(avg_pwr_db)=-60.98017247075392
# guess_threshold=-54.71507782366146
#  62%|██████████████████████████████████████████████▉                            | 15/24 [05:37<03:33, 23.76s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-10000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-10000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.198502811460486
# np.mean(avg_pwr_db)=-61.38580521899384
# guess_threshold=-54.79215401522716
#  67%|██████████████████████████████████████████████████                         | 16/24 [06:00<03:07, 23.47s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-10000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-10000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-10000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-10000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.47994612980755
# np.mean(avg_pwr_db)=-60.66232806952106
# guess_threshold=-54.571137099664305
#  71%|█████████████████████████████████████████████████████▏                     | 17/24 [06:28<02:52, 24.71s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-0-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-47.82161953394183
# np.mean(avg_pwr_db)=-58.952962251264665
# guess_threshold=-53.38729089260325
#  75%|████████████████████████████████████████████████████████▎                  | 18/24 [07:01<02:42, 27.12s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.39201664272464
# np.mean(avg_pwr_db)=-60.5326972186079
# guess_threshold=-54.462356930666274
#  79%|███████████████████████████████████████████████████████████▍               | 19/24 [07:34<02:24, 28.92s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-6-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.121435954360734
# np.mean(avg_pwr_db)=-61.771019925474704
# guess_threshold=-54.94622793991772
#  83%|██████████████████████████████████████████████████████████████▌            | 20/24 [08:09<02:02, 30.69s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-4-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.64923082330388
# np.mean(avg_pwr_db)=-61.73239982302937
# guess_threshold=-55.190815323166625
#  88%|█████████████████████████████████████████████████████████████████▋         | 21/24 [08:38<01:31, 30.44s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-2-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.94617263090624
# np.mean(avg_pwr_db)=-61.62512093919811
# guess_threshold=-55.28564678505218
#  92%|████████████████████████████████████████████████████████████████████▊      | 22/24 [09:05<00:58, 29.14s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-5000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-5000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-5000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-7-sendsps-5000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-47.50405975360874
# np.mean(avg_pwr_db)=-61.716704811828436
# guess_threshold=-54.61038228271859
#  96%|███████████████████████████████████████████████████████████████████████▉   | 23/24 [09:32<00:28, 28.68s/it]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-20000000.s16.zst.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-20000000.s16.zst.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-20000000.s16.zst.sigmf-data
#  SigMF-Meta file: data/gamutrf/gamutrf-nz-nonanon-wifi/wifi-encoding-1-sendsps-20000000.s16.zst.sigmf-meta
#
# np.max(avg_pwr_db)=-48.9617070845665
# np.mean(avg_pwr_db)=-61.484913116906846
# guess_threshold=-55.22331010073667
# 100%|███████████████████████████████████████████████████████████████████████████| 24/24 [10:00<00:00, 25.03s/it]
