# %%
import glob

from pathlib import Path
from tqdm import tqdm

import annotation_utils
import data as data_class
# Out:
# /home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/cupyx/jit/_interface.py:173: FutureWarning: cupyx.jit.rawkernel is experimental. The interface can change in the future.
#   cupy._util.experimental('cupyx.jit.rawkernel')

# %%
data_globs = {
    "mini2_video": [
        "data/gamutrf/gamutrf-arl/01_30_23/mini2_iq_label/*.sigmf-meta",
    ],
}

# %%
for label in data_globs:
    for data_glob in data_globs[label]:
        for f in tqdm(glob.glob(str(Path(data_glob)))):
            # annotation_utils.annotate(f, label=label, avg_window_len=256, avg_duration=0.25, debug=True, estimate_frequency=True, spectral_energy_threshold=0.99, force_threshold_db=-40)

            data_obj = data_class.Data(f)
            annotation_utils.reset_annotations(data_obj)
            annotation_utils.annotate(f, label="mini2_video", avg_window_len=256, avg_duration=0.25, debug=True, estimate_frequency=True, spectral_energy_threshold=0.99, force_threshold_db=-40, overwrite=False, min_bandwidth=10e6)
            annotation_utils.annotate(f, label="mini2_telem", avg_window_len=256, avg_duration=0.25, debug=True, estimate_frequency=True, spectral_energy_threshold=0.99, force_threshold_db=-40, overwrite=False, max_bandwidth=5e6)
# Out:
#   0%|                                                                                                                                                                                                                                                                 | 0/5 [00:00<?, ?it/s]/home/ltindall/.pyenv/versions/3.10.9/envs/rfml-dev/lib/python3.10/site-packages/sigmf/sigmffile.py:914: UserWarning: Compliant Dataset `data/gamutrf/gamutrf-arl/01_30_23/mini2_iq_label/gamutrf_recording_ettus__gain40_1675089106_5735500000Hz_20480000sps.s16.sigmf-data` exists but "core:dataset" is also defined; using `data/gamutrf/gamutrf-arl/01_30_23/mini2_iq_label/gamutrf_recording_ettus__gain40_1675089106_5735500000Hz_20480000sps.s16.sigmf-data`
#   warnings.warn(f'Compliant Dataset `{compliant_data_fn}` exists but '
# Loaded
#  Data file: data/gamutrf/gamutrf-arl/01_30_23/mini2_iq_label/gamutrf_recording_ettus__gain40_1675089106_5735500000Hz_20480000sps.s16.sigmf-data
# ...
